# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %% [markdown]
# Types of Datastructure in pandas :
# - 1 D -> Series
# - 2 D -> Dataframe

# %%
sr = pd.Series([23,1,32,3,54,8])
print(type(sr))
# Out:
# <class 'pandas.Series'>

# %%
data = {
    "Name":["Krish","Rohit","Dhruv"],
    "Age":[23,34,45],
    "City":["Delhi","Mumbai","Noida"]
}

# %%
df = pd.DataFrame(data)

# %%
df
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %% [markdown]
# Generate the range of date

# %%
dr = pd.date_range('20260113','20260312',freq="B")
print(dr)
# Out:
# DatetimeIndex(['2026-01-13', '2026-01-14', '2026-01-15', '2026-01-16',
#                '2026-01-19', '2026-01-20', '2026-01-21', '2026-01-22',
#                '2026-01-23', '2026-01-26', '2026-01-27', '2026-01-28',
#                '2026-01-29', '2026-01-30', '2026-02-02', '2026-02-03',
#                '2026-02-04', '2026-02-05', '2026-02-06', '2026-02-09',
#                '2026-02-10', '2026-02-11', '2026-02-12', '2026-02-13',
#                '2026-02-16', '2026-02-17', '2026-02-18', '2026-02-19',
#                '2026-02-20', '2026-02-23', '2026-02-24', '2026-02-25',
#                '2026-02-26', '2026-02-27', '2026-03-02', '2026-03-03',
#                '2026-03-04', '2026-03-05', '2026-03-06', '2026-03-09',
#                '2026-03-10', '2026-03-11', '2026-03-12'],
#               dtype='datetime64[us]', freq='B')

# %% [markdown]
# Table of random numbers

# %%
df = pd.DataFrame(np.random.randint(1,100,(4,5)))
df
# Out:
#     0   1   2   3   4
# 0  43  31  99  96  24
# 1  74  45  41  47  30
# 2  18  66  65  47   4
# 3  45  43  13  53  86

# %%
df = pd.DataFrame(np.random.randn(3,4))
df
# Out:
#           0         1         2         3
# 0 -1.007983 -1.492389  0.166816 -1.317901
# 1  0.713164 -0.054220  0.058299 -0.998220
# 2  0.164089  1.392694 -0.181613  2.079548

# %%
data = pd.read_csv('dataset.csv')

# %%
data.head(20)
# Out:
#     OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0      1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1       500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2      1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3      1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4       281  2023-11-16   2023-11-19  Customer_208    Furniture  South
# 5      1659  2022-05-26   2022-06-01  Customer_237     Clothing  South
# 6      1329  2022-07-25   2022-07-28   Customer_98         Food   West
# 7       211  2024-04-01   2024-04-02  Customer_271     Clothing  South
# 8      1261  2022-07-11   2022-07-14  Customer_359  Electronics   East
# 9      1910  2024-07-28   2024-08-03  Customer_233  Electronics  North
# 10      189  2022-01-02   2022-01-09  Customer_247  Electronics   West
# 11     1950  2024-02-06   2024-02-16  Customer_496         Food   West
# ...

# %%
data.tail()
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1995      894  2022-06-05   2022-06-08  Customer_247    Furniture  South
# 1996     1837  2024-03-30   2024-04-08  Customer_427         Food  North
# 1997     1702  2023-06-01   2023-06-07  Customer_135    Furniture   East
# 1998      957  2024-02-14   2024-02-19   Customer_64    Furniture   West
# 1999      939  2024-12-13   2024-12-22   Customer_25  Electronics  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# 1995  Wholesale         6     248.45            False     1490.700
# 1996  Wholesale        16     194.62             True     2802.528
# 1997     Online         6     118.02            False      708.120
# 1998     Online         6     487.15             True     2630.610
# 1999  Wholesale        14     136.99            False     1917.860

# %%
data.index
# Out:
# RangeIndex(start=0, stop=2000, step=1)

# %%
data.columns
# Out:
# Index(['OrderID', 'OrderDate', 'ShipmentDate', 'CustomerName', 'Category',
#        'Region', 'Channel', 'Quantity', 'UnitPrice', 'DiscountApplied',
#        'SalesAmount'],
#       dtype='str')

# %%
df.to_numpy
# Out:
# <bound method DataFrame.to_numpy of           0         1         2         3
# 0 -1.007983 -1.492389  0.166816 -1.317901
# 1  0.713164 -0.054220  0.058299 -0.998220
# 2  0.164089  1.392694 -0.181613  2.079548>

# %%
print(data.describe())
# Out:
#            OrderID     Quantity    UnitPrice  SalesAmount
# count  2000.000000  2000.000000  2000.000000  2000.000000
# mean   1000.500000    10.195500   253.750990  2458.940332
# std     577.494589     5.419868   141.864924  2024.978250
# min       1.000000     1.000000     5.120000     6.550000
# 25%     500.750000     5.750000   130.815000   812.524500
# 50%    1000.500000    10.000000   253.375000  1901.762500
# 75%    1500.250000    15.000000   376.955000  3679.098000
# max    2000.000000    19.000000   499.840000  9059.010000

# %%
data.T
# Out:
#                          0             1             2             3     \
# OrderID                  1152           500          1337          1033
# OrderDate          2024-07-27    2024-02-23    2022-04-27    2022-02-24
# ShipmentDate       2024-08-04    2024-03-04    2022-05-06    2022-03-02
# CustomerName     Customer_327  Customer_426  Customer_379  Customer_381
# Category          Electronics   Electronics   Electronics          Food
# Region                   West         North          East          West
# Channel             Wholesale        Online        Retail     Wholesale
# Quantity                   15            17             6            12
# UnitPrice              271.72        433.52        434.97        283.51
# DiscountApplied          True         False         False          True
# SalesAmount           3668.22       7369.84       2609.82      3061.908
#
#                          4             5            6             7     \
# ...

# %%
data
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 0        1152  2024-07-27   2024-08-04  Customer_327  Electronics   West
# 1         500  2024-02-23   2024-03-04  Customer_426  Electronics  North
# 2        1337  2022-04-27   2022-05-06  Customer_379  Electronics   East
# 3        1033  2022-02-24   2022-03-02  Customer_381         Food   West
# 4         281  2023-11-16   2023-11-19  Customer_208    Furniture  South
# ...       ...         ...          ...           ...          ...    ...
# 1995      894  2022-06-05   2022-06-08  Customer_247    Furniture  South
# 1996     1837  2024-03-30   2024-04-08  Customer_427         Food  North
# 1997     1702  2023-06-01   2023-06-07  Customer_135    Furniture   East
# 1998      957  2024-02-14   2024-02-19   Customer_64    Furniture   West
# 1999      939  2024-12-13   2024-12-22   Customer_25  Electronics  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# ...

# %%
data.sort_index(axis=1)
# Out:
#          Category    Channel  CustomerName  DiscountApplied   OrderDate  \
# 0     Electronics  Wholesale  Customer_327             True  2024-07-27
# 1     Electronics     Online  Customer_426            False  2024-02-23
# 2     Electronics     Retail  Customer_379            False  2022-04-27
# 3            Food  Wholesale  Customer_381             True  2022-02-24
# 4       Furniture     Retail  Customer_208             True  2023-11-16
# ...           ...        ...           ...              ...         ...
# 1995    Furniture  Wholesale  Customer_247            False  2022-06-05
# 1996         Food  Wholesale  Customer_427             True  2024-03-30
# 1997    Furniture     Online  Customer_135            False  2023-06-01
# 1998    Furniture     Online   Customer_64             True  2024-02-14
# 1999  Electronics  Wholesale   Customer_25            False  2024-12-13
#
#       OrderID  Quantity Region  SalesAmount ShipmentDate  UnitPrice
# ...

# %%
data.sort_values("Quantity")
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 735      1650  2022-06-01   2022-06-09  Customer_255         Food  North
# 228      1621  2022-10-18   2022-10-27   Customer_16         Food   East
# 1070     1610  2022-02-20   2022-02-28  Customer_434     Clothing  South
# 748       922  2024-09-14   2024-09-16  Customer_281  Electronics  North
# 1117      956  2022-11-26   2022-11-29  Customer_382     Clothing  South
# ...       ...         ...          ...           ...          ...    ...
# 359       681  2022-01-28   2022-02-03  Customer_101     Clothing  North
# 1055      599  2022-06-15   2022-06-23  Customer_113  Electronics  South
# 1607     1831  2023-02-04   2023-02-14  Customer_377         Food   East
# 1208      192  2023-03-29   2023-04-06  Customer_490         Food  North
# 1474     1418  2024-12-18   2024-12-19  Customer_167     Clothing   East
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# ...

# %%
data.sort_values("OrderDate")
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1082      559  2022-01-01   2022-01-10  Customer_340     Clothing  North
# 1212      743  2022-01-01   2022-01-04  Customer_448     Clothing   West
# 100      1364  2022-01-02   2022-01-07  Customer_278    Furniture  North
# 1189      146  2022-01-02   2022-01-08  Customer_420    Furniture   West
# 564      1459  2022-01-02   2022-01-11  Customer_479         Food  North
# ...       ...         ...          ...           ...          ...    ...
# 271      1548  2024-12-28   2025-01-05  Customer_451    Furniture  South
# 1156      461  2024-12-29   2025-01-07  Customer_156         Food  North
# 1692     1695  2024-12-29   2024-12-30  Customer_180  Electronics   West
# 728       568  2024-12-31   2025-01-07  Customer_246     Clothing  South
# 723         2  2024-12-31   2025-01-03  Customer_104    Furniture  North
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# ...

# %% [markdown]
# Indexing and Selecting

# %%
data[["OrderDate","Quantity"]]
# Out:
#        OrderDate  Quantity
# 0     2024-07-27        15
# 1     2024-02-23        17
# 2     2022-04-27         6
# 3     2022-02-24        12
# 4     2023-11-16        15
# ...          ...       ...
# 1995  2022-06-05         6
# 1996  2024-03-30        16
# 1997  2023-06-01         6
# 1998  2024-02-14         6
# 1999  2024-12-13        14
#
# [2000 rows x 2 columns]

# %%
data[2:10][["OrderDate","SalesAmount"]]
# Out:
#     OrderDate  SalesAmount
# 2  2022-04-27     2609.820
# 3  2022-02-24     3061.908
# 4  2023-11-16      663.660
# 5  2022-05-26     1007.400
# 6  2022-07-25     3325.530
# 7  2024-04-01     2117.930
# 8  2022-07-11     1775.040
# 9  2024-07-28     2389.248

# %%
grouped = data.groupby(["Category"]).sum()[["SalesAmount"]]

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(grouped.index,grouped["SalesAmount"])
plt.xlabel("Category")
plt.ylabel("sale")
plt.show()

# %%
data.sample(n=30)
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 1203      651  2024-04-10   2024-04-20  Customer_423     Clothing  North
# 220       299  2024-04-17   2024-04-25  Customer_177         Food   West
# 1520      595  2024-05-08   2024-05-12  Customer_377         Food  South
# 541      1696  2023-03-01   2023-03-06  Customer_487  Electronics  South
# 1087      839  2023-01-31   2023-02-07   Customer_60  Electronics   East
# 1135      716  2024-11-29   2024-11-30   Customer_72     Clothing  North
# 1893      963  2023-05-29   2023-06-07   Customer_54         Food   West
# 510      1832  2024-02-03   2024-02-05  Customer_279    Furniture   West
# 151       970  2023-01-31   2023-02-05  Customer_187     Clothing  North
# 150      1521  2023-05-10   2023-05-14  Customer_366         Food   East
# 837      1149  2024-08-21   2024-08-31  Customer_375     Clothing   East
# 891      1762  2023-02-10   2023-02-15  Customer_413  Electronics  North
# ...

# %%
data['Quantity'].where(lambda x:x>4).count()
# Out:
# np.int64(1611)

# %%
data.query('Quantity>18')
# Out:
#       OrderID   OrderDate ShipmentDate  CustomerName     Category Region  \
# 7         211  2024-04-01   2024-04-02  Customer_271     Clothing  South
# 10        189  2022-01-02   2022-01-09  Customer_247  Electronics   West
# 16        719  2024-07-08   2024-07-14  Customer_310  Electronics   West
# 57        419  2024-11-08   2024-11-15  Customer_107         Food  South
# 58        480  2023-05-20   2023-05-25   Customer_58  Electronics   West
# ...       ...         ...          ...           ...          ...    ...
# 1893      963  2023-05-29   2023-06-07   Customer_54         Food   West
# 1900     1107  2022-02-08   2022-02-09  Customer_290    Furniture   West
# 1913      405  2024-09-04   2024-09-07  Customer_265  Electronics  North
# 1935     1944  2024-04-15   2024-04-21  Customer_126  Electronics  South
# 1964      914  2022-10-13   2022-10-21  Customer_125     Clothing   West
#
#         Channel  Quantity  UnitPrice  DiscountApplied  SalesAmount
# ...

# %%
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)


df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)


df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[8, 9, 10, 11],
)

# %%
dt = [df1,df2,df3]

# %%
pd.concat(dt)
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
sale_data = pd.read_csv("data/fact_sales.csv")
customer_data = pd.read_csv("data/dim_customers_cleaned.csv")
product_data = pd.read_csv("data/dim_products.csv")

# %%
concat_data = pd.merge(sale_data[["order_number","order_date","shipping_date","customer_key","sales_amount"]],customer_data[["customer_key","country","gender","first_name"]],on='customer_key')

# %%
concat_data.groupby(["country","gender"]).sum()["sales_amount"]
# Out:
# country         gender
# Australia       Female    4634558
#                 Male      4425614
# Canada          Female    1011343
#                 Male       966395
# France          Female    1271711
#                 Male      1365721
# Germany         Female    1536211
#                 Male      1344305
# United Kingdom  Female    1610000
#                 Male      1771689
# United States   Female    4614523
#                 Male      4547671
# Name: sales_amount, dtype: int64

# %%
data.pivot_table(index='Region',columns="Category",values=["SalesAmount","Quantity"],aggfunc=['sum','mean'])
# Out:
#               sum                                                      \
#          Quantity                             SalesAmount
# Category Clothing Electronics  Food Furniture    Clothing Electronics
# Region
# East         1431        1442  1124      1081  330373.499  360818.577
# North        1251        1216  1237      1243  289477.314  301370.412
# South        1332        1278  1364      1466  314403.655  316755.458
# West         1375        1363  1094      1094  350246.180  338547.522
#
#                                        mean                                    \
#                                    Quantity
# Category        Food   Furniture   Clothing Electronics       Food  Furniture
# Region
# East      250346.189  262142.428  10.221429    9.944828  10.311927  10.009259
# North     296408.627  328052.310  10.425000   10.761062   9.896000  10.024194
# South     302344.959  356538.774   9.940299   10.306452   9.884058  10.779412
# ...
